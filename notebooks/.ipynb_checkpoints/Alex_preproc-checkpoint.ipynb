# %%
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.impute import KNNImputer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.svm import SVR

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder

from sklearn.compose import ColumnTransformer

# %%
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import make_union

# %%
from sklearn.impute import SimpleImputer

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-2.1.2-py3-none-manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in /home/ak/.pyenv/versions/3.10.6/envs/real-estate-price-prediction/lib/python3.10/site-packages (from xgboost) (2.1.2)
# Collecting nvidia-nccl-cu12 (from xgboost)
#   Downloading nvidia_nccl_cu12-2.23.4-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: scipy in /home/ak/.pyenv/versions/3.10.6/envs/real-estate-price-prediction/lib/python3.10/site-packages (from xgboost) (1.14.1)
# Downloading xgboost-2.1.2-py3-none-manylinux_2_28_x86_64.whl (153.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.9/153.9 MB 14.8 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nccl_cu12-2.23.4-py3-none-manylinux2014_x86_64.whl (199.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.0/199.0 MB 22.7 MB/s eta 0:00:0000:0100:01
# Installing collected packages: nvidia-nccl-cu12, xgboost
# Successfully installed nvidia-nccl-cu12-2.23.4 xgboost-2.1.2
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python -m pip install --upgrade pip

# %%
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor

# %%
from sklearn.model_selection import cross_validate

# %%
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../raw_data/belgian_property_prices.csv')

# %%
df.isnull().sum()/4769
# Out:
# as_built_plan                                     0.499266
# available_as_of                                   0.179912
# basement                                          0.563430
# bathrooms                                         0.051793
# bedroom_1_surface                                 0.336968
# bedroom_2_surface                                 0.349130
# bedroom_3_surface                                 0.450199
# bedrooms                                          0.006291
# building_condition                                0.059761
# co2_emission                                      0.594045
# cadastral_income                                  0.226043
# connection_to_sewer_network                       0.574544
# construction_year                                 0.278046
# covered_parking_spaces                            0.430279
# dining_room                                       0.719438
# double_glazing                                    0.136507
# energy_class                                      0.000000
# external_reference                                0.091843
# flood_zone_type                                   0.416649
# furnished                                         0.557979
# garden_surface                                    0.542881
# gas_water__electricity                            0.324177
# heating_type                                      0.132942
# kitchen_surface                                   0.439295
# kitchen_type                                      0.169847
# latest_land_use_designation                       0.529461
# living_area                                       0.014259
# living_room_surface                               0.368002
# number_of_frontages                               0.066052
# office                                            0.697421
# outdoor_parking_spaces                            0.506395
# planning_permission_obtained                      0.677291
# possible_priority_purchase_right                  0.539316
# primary_energy_consumption                        0.041728
# proceedings_for_breach_of_planning_regulations    0.634934
# reference_number_of_the_epc_report                0.000000
# street_frontage_width                             0.560705
# subdivision_permit                                0.619836
# surface_of_the_plot                               0.043405
# surroundings_type                                 0.523380
# tv_cable                                          0.694066
# tenement_building                                 0.009855
# toilets                                           0.088488
# website                                           0.169218
# width_of_the_lot_on_the_street                    0.582931
# yearly_theoretical_total_energy_consumption       0.620046
# housenumber                                       0.023695
# street                                            0.017823
# city                                              0.010275
# postal                                            0.006920
# state                                             0.008807
# lat                                               0.006920
# lng                                               0.006920
# price                                             0.000000
# dtype: float64

# %%
pd.crosstab(index = df['energy_class'], columns='count')
# Out:
# col_0          count
# energy_class
# A                172
# A+                11
# A++                2
# B                665
# C                812
# C_B                1
# D                882
# E                747
# F                802
# G                483
# Not specified    193

# %%
pd.crosstab(index = df['available_as_of'], columns='count')
# Out:
# col_0                    count
# available_as_of
# After signing the deed    2909
# At delivery                 84
# Depending on the tenant    198
# Immediately                378
# To be defined              343

# %%
df = df.drop_duplicates()

# %%
y = df['price']

# %%
X = df.drop(columns=['price'])

# %%
len(y)
# Out:
# 4753

# %% [raw]
# # SVM Regressor with Grid Search on imputators

# %%
imputer_options = {
    'knn': KNNImputer(),
    'mean': SimpleImputer(strategy='mean'),
    'median': SimpleImputer(strategy='median'),
    'most_frequent': SimpleImputer(strategy='most_frequent')
}

num_transformer = Pipeline([
    ('imputer', KNNImputer()),
    ('scaler', StandardScaler())
])

cat_transformer = OneHotEncoder(handle_unknown='ignore')

numerical_features = X.select_dtypes(include=['number']).columns.tolist()

categorical_features = X.select_dtypes(include=['object', 'category']).columns.tolist()

preprocessor = ColumnTransformer([
    ('num_transformer', num_transformer, numerical_features),
    ('cat_transformer', cat_transformer, categorical_features)
])

pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('svr', SVR())
])
param_grid = [
    {
        'preprocessor__num_transformer__imputer': [KNNImputer()],
        'preprocessor__num_transformer__imputer__n_neighbors': [2, 3, 5, 10, 20]  # Parameters specific to KNNImputer
    },
    {
        'preprocessor__num_transformer__imputer': [
            SimpleImputer(strategy='mean'),
            SimpleImputer(strategy='median'),
            SimpleImputer(strategy='most_frequent')
        ]
        # No extra parameters needed for SimpleImputer
    }
]
grid_search = GridSearchCV(
    pipeline, 
    param_grid=param_grid,
    cv=5,
    scoring="r2"
)

grid_search.fit(X, y)

grid_search.best_params_

# %%
grid_search.best_score_

# %%
# Decision Tree

# %%
tree = DecisionTreeRegressor()

# %%
num_transformer = Pipeline([
    ('imputer', KNNImputer())
])

cat_transformer = OneHotEncoder(handle_unknown='ignore')

numerical_features = X.select_dtypes(include=['number']).columns.tolist()

categorical_features = X.select_dtypes(include=['object', 'category']).columns.tolist()

preprocessor = ColumnTransformer([
    ('num_transformer', num_transformer, numerical_features),
    ('cat_transformer', cat_transformer, categorical_features)
])

pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('tree', DecisionTreeRegressor())
])

param_grid = [
    {
        'preprocessor__num_transformer__imputer__n_neighbors':[10],
         
          'tree__max_depth':[None,2,5,10,20],
        'tree__min_samples_split': [10, 20, 30]
    }
]

grid_search = GridSearchCV(
    pipeline, 
    param_grid=param_grid,
    cv=5,
    scoring="r2"
)

# %%
grid_search.fit(X, y)
# Out:
# /home/ak/.pyenv/versions/3.10.6/envs/real-estate-price-prediction/lib/python3.10/site-packages/numpy/ma/core.py:2881: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num_transformer',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           KNNImputer())]),
#                                                                          ['as_built_plan',
#                                                                           'basement',
#                                                                           'bathrooms',
#                                                                           'bedroom_1_surface',
#                                                                           'bedroom_2_surface',
#                                                                           'bedroom_3_surface',
#                                                                           'bedrooms',
#                                                                           'co2_emission',
#                                                                           'cadastral_income',
#                                                                           'connection_to_sewer_network',
#                                                                           'construction_year',
#                                                                           '...
#                                                                           'heating_type',
#                                                                           'kitchen_type',
#                                                                           'latest_land_use_designation',
#                                                                           'reference_number_of_the_epc_report',
#                                                                           'surroundings_type',
#                                                                           'website',
#                                                                           'housenumber',
#                                                                           'street',
#                                                                           'city',
#                                                                           'state'])])),
#                                        ('tree', DecisionTreeRegressor())]),
#              param_grid=[{'preprocessor__num_transformer__imputer__n_neighbors': [10],
#                           'tree__max_depth': [None, 2, 5, 10, 20],
#                           'tree__min_samples_split': [10, 20, 30]}],
#              scoring='r2')

# %%
grid_search.best_params_
# Out:
# {'preprocessor__num_transformer__imputer__n_neighbors': 10,
#  'tree__max_depth': None,
#  'tree__min_samples_split': 30}

# %%
grid_search.best_score_
# Out:
# np.float64(0.5752696758549486)

# %%
#XGBoost

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size = 0.3, random_state = 42  # TEST = 30%
)

# Use the same function above for the validation set
X_test, X_val, y_test, y_val = train_test_split(
    X_test, y_test, test_size = 0.5, random_state = 42  # TEST = 15%
)

# %%
rmsle_neg = make_scorer(
    lambda y_true, y_pred: mean_squared_log_error(y_true, y_pred)**0.5,
    greater_is_better=False
)

# %%
num_transformer = Pipeline([
    ('imputer', KNNImputer())
])

cat_transformer = OneHotEncoder(handle_unknown='ignore')

numerical_features = X.select_dtypes(include=['number']).columns.tolist()

categorical_features = X.select_dtypes(include=['object', 'category']).columns.tolist()

preprocessor = ColumnTransformer([
    ('num_transformer', num_transformer, numerical_features),
    ('cat_transformer', cat_transformer, categorical_features)
])

pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('xgb', XGBRegressor())
])

param_grid = [
    {
        'preprocessor__num_transformer__imputer__n_neighbors':[10],
         'xgb__n_estimators':[None,2,10,20],
        'xgb__learning_rate': [0.1, 0.2]
    }
]

grid_search = GridSearchCV(
    pipeline, 
    param_grid=param_grid,
    cv=5,
    scoring="r2"
)
